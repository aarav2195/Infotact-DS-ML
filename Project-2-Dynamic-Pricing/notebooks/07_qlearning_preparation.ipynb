# %%
import os
import sys

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
import numpy as np

from src.q_learning_utils import (state_to_index,initialize_q_table)

# %%
q_table = initialize_q_table()
print(q_table.shape)
# Out:
# (1581, 5)

# %%
print(state_to_index(50,30))
print(state_to_index(25,15))
print(state_to_index(10,5))
print(state_to_index(0,0))
# Out:
# 1580
# 790
# 315
# 0

# %%
states = []

for rooms in range(51):
    for days in range(31):
        states.append({
            "Rooms Remaining": rooms,
            "Days Remaining": days,
            "State Index": state_to_index(rooms,days)
        })
state_df = pd.DataFrame(states)
state_df.head()
# Out:
#    Rooms Remaining  Days Remaining  State Index
# 0                0               0            0
# 1                0               1            1
# 2                0               2            2
# 3                0               3            3
# 4                0               4            4

# %%
state_df.to_csv(r"..\data\processed\state_space.csv",index=False)
print("State space saved.")
# Out:
# State space saved.

# %%
print("Total States : ",len(state_df))
print("Unique States : ",state_df["State Index"].nunique())
# Out:
# Total States :  1581
# Unique States :  1581
