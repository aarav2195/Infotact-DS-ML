# %%
import os
import sys

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np

from src.config import *

# %% [markdown]
# # Custom Hotel Pricing Environment
#
# The reinforcement learning agent requires an environment that simulates hotel bookings.
#
# The environment maintains the current inventory, booking horizon, and accepts pricing actions from the agent.
#
# Each interaction returns:
#
# - State
# - Reward
# - Done flag
# - Additional information

# %%
from src.environment import HotelPricingEnv
env = HotelPricingEnv()
state,_ = env.reset()
print(state)
# Out:
# [50 30]

# %%
next_state,reward,done,_,_ =env.step(2)
print(next_state)
print(reward)
print(done)
# Out:
# [50 29]
# 0
# False
