# %%
import os
import sys

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.append(project_root)

print("Project Root:", project_root)
# Out:
# Project Root: e:\AARAV\Infotact-DS-ML\Project-2-Dynamic-Pricing

# %%
from src.environment import HotelPricingEnv

# %%
env = HotelPricingEnv()
state,_ = env.reset()
print(state)
# Out:
# [50 30]

# %%
import numpy as np

for i in range(5):
    action = np.random.randint(0,5)
    state,reward,done,_,info = env.step(action)
    print(f"Step {i+1}")
    print("Price: ",info["price"])
    print("Demand: ",info["demand"])
    print("Rooms Sold: ",info["rooms_sold"])
    print("Reward: ",reward)
    print("State: ",state)
    print("----------------------------------")
# Out:
# Step 1
# Price:  160
# Demand:  1
# Rooms Sold:  1
# Reward:  160
# State:  [49 29]
# ----------------------------------
# Step 2
# Price:  100
# Demand:  3
# Rooms Sold:  3
# Reward:  300
# State:  [46 28]
# ----------------------------------
# Step 3
# Price:  100
# Demand:  2
# Rooms Sold:  2
# Reward:  200
# State:  [44 27]
# ----------------------------------
# Step 4
# Price:  80
# Demand:  1
# Rooms Sold:  1
# Reward:  80
# State:  [43 26]
# ----------------------------------
# Step 5
# Price:  140
# Demand:  1
# Rooms Sold:  1
# Reward:  140
# State:  [42 25]
# ----------------------------------
